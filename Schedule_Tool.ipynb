# %% [markdown]
# # Schedule Tool — Annotated Version (English comments)
#
# - Generated on: 2025-08-14T03:43:27
# - This copy adds **English explanations** as Markdown cells and **inline comments** at the top of each code cell.
# - Note: Some steps rely on **Polars**/**fastexcel**/**networkx**. Install the required packages before running.

# %% [markdown]
# ## Step 1 — Import libraries
#
# - Import core data libraries: pandas, numpy, glob, os, pathlib.
# - Date/time helpers: datetime, timedelta, time.
# - Excel I/O: fastexcel, xlsxwriter.
# - Graphs for swap relationships: networkx.
# - Optional: polars for faster I/O and melt/group operations (can be replaced by pandas if needed).

# %%
# Step 1 — Import libraries
# - Import core data libraries: pandas, numpy, glob, os, pathlib.
# - Date/time helpers: datetime, timedelta, time.
# - Excel I/O: fastexcel, xlsxwriter.
# - Graphs for swap relationships: networkx.
# - Optional: polars for faster I/O and melt/group operations (can be replaced by pandas if needed).
# ---

import pandas as pd
import glob
from datetime import date, timedelta
import numpy as np
from datetime import datetime
from datetime import time
from pathlib import Path
from collections import OrderedDict
import polars as pl
import fastexcel
import xlsxwriter
import os
import networkx as nx
import shutil
import tempfile
from IPython.display import display, HTML

# %% [markdown]
# ## Step 2 — (Commented) process_schedule() & weekly Excel export
#
# - Legacy pipeline to read sheets (e.g., Lodging/Non_Lodging), drop 'shift*' columns, and melt to long format.
# - Adds LOB column, combines sheets, standardizes Date, and derives Week (Monday start).
# - Splits by week and exports each week to an Excel file.
# - This block is currently commented out and not executed.

# %%
# Step 2 — (Commented) process_schedule() & weekly Excel export
# - Legacy pipeline to read sheets (e.g., Lodging/Non_Lodging), drop 'shift*' columns, and melt to long format.
# - Adds LOB column, combines sheets, standardizes Date, and derives Week (Monday start).
# - Splits by week and exports each week to an Excel file.
# - This block is currently commented out and not executed.
# ---

# def process_schedule(sheet_name):
#     df = pd.read_excel(r'C:/Users/ADMIN/OneDrive/Desktop/book1.xlsx', sheet_name=sheet_name)
#     df = df[[col for col in df.columns if not str(col).lower().startswith("shift")]]
#     id_vars = ['IEX ID', 'Name','TL'] #, 'Status', 'Sec Status'
#     df_melted = pd.melt(df, id_vars=id_vars, var_name='Date', value_name='Shift')
#     df_melted = df_melted[df_melted['Shift'].notna()]
#     df_melted['LOB'] = sheet_name

#     return df_melted

# schedule_lodging = process_schedule("Lodging")
# schedule_nonlodging = process_schedule("Non_Lodging")
# combined_schedule = pd.concat([schedule_lodging, schedule_nonlodging], ignore_index=True)

# combined_schedule['Date'] = pd.to_datetime(combined_schedule['Date'], errors='coerce')
# combined_schedule['Week'] = combined_schedule['Date'] - pd.to_timedelta(combined_schedule['Date'].dt.weekday, unit='d')

# output_folder = "C:/Users/ADMIN/Concentrix Corporation/WFM-Expedia-HCM - Branding files/Rawdata/INPUT_SCHEDULE/SCHEDULE_VN"
# os.makedirs(output_folder, exist_ok=True)

# for week, group in combined_schedule.groupby('Week'):
#     week_str = week.strftime('%Y_%m_%d')
#     file_path = os.path.join(output_folder, f"Schedule_{week_str}.xlsx")
#     sheet_name = f"Schedule_{week_str}"

#     with pd.ExcelWriter(file_path, engine='xlsxwriter') as writer:
#         pivot_schedule = group.pivot_table(
#             index=['IEX ID', 'Name', 'TL', 'LOB'], #'Status', 'Sec Status', 
#             columns='Date',
#             values='Shift',
#             aggfunc='first'
#         )
#         pivot_schedule.columns = pivot_schedule.columns.astype(str)

#         pivot_schedule.to_excel(writer, sheet_name=sheet_name, index=True)

# %% [markdown]
# ## Step 3 — input_data() & process_schedule_shift()
#
# - input_data(folder_path): scan Excel/CSV files, read with Polars (or CSV), set headers, and unify schema.
# - Melt schedule to long format with columns: Week, IEX ID, Name, TL, LOB, Date, Shift.
# - Parse 'Date' with multiple formats to ensure robustness.
# - process_schedule_shift(df, shift_column_name): split 'HHMM-HHMM' into Start_Shift/End_Shift.
# - Classify Day_Type (Day/Night) and Shift_Type (Morning/Afternoon/Night).

# %%
# Step 3 — input_data() & process_schedule_shift()
# - input_data(folder_path): scan Excel/CSV files, read with Polars (or CSV), set headers, and unify schema.
# - Melt schedule to long format with columns: Week, IEX ID, Name, TL, LOB, Date, Shift.
# - Parse 'Date' with multiple formats to ensure robustness.
# - process_schedule_shift(df, shift_column_name): split 'HHMM-HHMM' into Start_Shift/End_Shift.
# - Classify Day_Type (Day/Night) and Shift_Type (Morning/Afternoon/Night).
# ---

def input_data(folder_path):
    file_paths = glob.glob(f"{folder_path}/*.xlsx") + glob.glob(f"{folder_path}/*.csv")
    df_list = []
    for file in file_paths:
        source_name = os.path.splitext(os.path.basename(file))[0]
        
        if file.endswith('.xlsx'):
            df = pl.read_excel(file, has_header=False)
            new_header = [str(item).strip() for item in df.row(0)]
            df = df.slice(1)
            df.columns = [str(col).strip() for col in new_header]
            
        elif file.endswith('.csv'):
            df = pl.read_csv(file)
            df = df.with_columns([pl.col(col).cast(pl.String) for col in df.columns])
        
        df = df.with_columns(pl.lit(source_name).alias("Week"))

        cols_to_choose = [col for col in ["Week", "IEX ID", "Name", "LOB", "TL"] if col in df.columns]
        cols_to_drop = [col for col in ['Status', 'Sec Status'] if col in df.columns]
        df = df.drop(cols_to_drop)
        
        df = df.melt(id_vars=cols_to_choose, variable_name="Date", value_name="Shift")
        
        df = df.with_columns(
            pl.coalesce([
                pl.col("Date").str.strptime(pl.Date, "%Y-%m-%d", strict=False),
                pl.col("Date").str.strptime(pl.Date, "%Y-%m-%d %H:%M:%S", strict=False)
            ]).alias("Date")
        )
        df_list.append(df)
    
    if df_list:
        merged_df = pl.concat(df_list, how='vertical')
    else:
        merged_df = pl.DataFrame()  # Tránh lỗi nếu không có file nào
    
    return merged_df

def process_schedule_shift(df, shift_column_name):
    mask = df[shift_column_name].str.contains("-", na=False)
    
    df["Start_Shift"] = df[shift_column_name].where(mask).str.split("-").str[0]
    df["End_Shift"] = df[shift_column_name].where(mask).str.split("-").str[1]
    df["Start_Shift"] = pd.to_datetime(df["Start_Shift"], format="%H%M", errors="coerce").dt.time
    df["End_Shift"] = pd.to_datetime(df["End_Shift"], format="%H%M", errors="coerce").dt.time
    def classify_day_type(shift_time):
        if isinstance(shift_time, time):
            return "Night_Shift" if shift_time >= time(18, 0) else "Day_Shift"
        return np.nan
    def classify_shift_type(shift_time):
        if shift_time is None:
            return None
        if isinstance(shift_time, time):
            if time(5, 0) <= shift_time < time(12, 0):
                return "Morning"
            elif time(12, 0) <= shift_time < time(18, 0):
                return "Afternoon"
            elif shift_time >= time(18, 0):
                return "Night"
            else:
                return "Day_Shift"
        return None
    df["Day_Type"] = df["Start_Shift"].apply(classify_day_type)
    df["Shift_Type"] = df["Start_Shift"].apply(classify_shift_type)
    return df

# %% [markdown]
# ## Step 4 — Path configuration and current processing Week
#
# - Define base directory and the target 'week' (e.g., 'Schedule_YYYY_MM_DD').
# - folder_paths: structured paths for schedule sources, VN team workbook, analysis outputs, and step-1 exports.

# %%
# Step 4 — Path configuration and current processing Week
# - Define base directory and the target 'week' (e.g., 'Schedule_YYYY_MM_DD').
# - folder_paths: structured paths for schedule sources, VN team workbook, analysis outputs, and step-1 exports.
# ---

first_glob = os.path.expanduser("~").replace("\\", "/")
test_path = f"{first_glob}/Concentrix Corporation"
if not os.path.exists(test_path):
    raise FileNotFoundError(f"Not found the path: {test_path}")

week = "Schedule_2026_05_04"

folder_paths = {
    "schedule_team":f'{first_glob}/Concentrix Corporation/WFM-Expedia-HCM - Branding files/Rawdata/INPUT_SCHEDULE/SCHEDULE_TEAM',
    "vn_team":f'{first_glob}/Concentrix Corporation/WFM-Expedia-HCM - Branding files/Schedule/Schedule (RTA version)/2026/2026-03/Schedule_WB0504.xlsx',
    "schedule_vn":f'{first_glob}/Concentrix Corporation/WFM-Expedia-HCM - Branding files/Rawdata/INPUT_SCHEDULE/SCHEDULE_VN',
    "analysis":f'{first_glob}/Concentrix Corporation/WFM-Expedia-HCM - Branding files/Rawdata/INPUT_SCHEDULE/SCHEDULE_ANALYSIS',
    "schedule_step_1":f'{first_glob}/Concentrix Corporation/WFM-Expedia-HCM - Branding files/Rawdata/INPUT_SCHEDULE/SCHEDULE_STEP_1'
}

# %% [markdown]
# ## Step 5 — load_and_merge_hc_data()
#
# - Read Headcount workbook with 'Active' and 'Inactive' sheets.
# - Normalize columns, add missing columns per sheet, keep consistent selected columns.
# - Concatenate sheets, parse 'LWD/Movement' as datetime and coerce 'IEX ID' to numeric.

# %%
# Step 5 — load_and_merge_hc_data()
# - Read Headcount workbook with 'Active' and 'Inactive' sheets.
# - Normalize columns, add missing columns per sheet, keep consistent selected columns.
# - Concatenate sheets, parse 'LWD/Movement' as datetime and coerce 'IEX ID' to numeric.
# ---

def load_and_merge_hc_data(excel_path: str) -> pd.DataFrame:
    selected_columns = ["Site","IEX ID", "OracleID", "Employee Name", "Alias", "Gender", "Email Id", "LWD/Movement", "Mini Team"]

    def read_and_process_sheet(sheet_name: str) -> pd.DataFrame:
        df = pd.read_excel(excel_path, sheet_name=sheet_name, header=None)
        df.columns = df.iloc[0]
        df = df[1:]
        for col in selected_columns:
            if col not in df.columns:
                df[col] = pd.NA
        df = df[selected_columns]
        return df

    active_df = read_and_process_sheet("Active")
    inactive_df = read_and_process_sheet("Inactive")
    combined_df = pd.concat([active_df, inactive_df], ignore_index=True)
    combined_df['LWD/Movement'] = pd.to_datetime(combined_df['LWD/Movement'], errors='coerce')
    combined_df['IEX ID'] = pd.to_numeric(combined_df['IEX ID'], errors='coerce')
    return combined_df

# hc = load_and_merge_hc_data(folder_paths['vn_team'])

# %% [markdown]
# ## Step 6 — get_most_frequent_shift() (Polars)
#
# - Filter rows with valid 'Shift' pattern 'HHMM-HHMM' (fallback to 'No Shift' if none).
# - Group by Week/IEX/Name/TL/LOB/Shift and count occurrences.
# - For each agent/week, pick the shift with the highest frequency.

# %%
# Step 6 — get_most_frequent_shift() (Polars)
# - Filter rows with valid 'Shift' pattern 'HHMM-HHMM' (fallback to 'No Shift' if none).
# - Group by Week/IEX/Name/TL/LOB/Shift and count occurrences.
# - For each agent/week, pick the shift with the highest frequency.
# ---

def get_most_frequent_shift(df):
    expected_cols = ["Week", "IEX ID", "Name", "TL", "LOB", "Shift"]
    existing_cols = [col for col in expected_cols if col in df.columns]
    df = df.select(existing_cols)
    shift_with_dash = df.filter(pl.col("Shift").str.contains("-"))
    if shift_with_dash.height > 0: df_filtered = shift_with_dash
    else: df_filtered = df.with_columns(pl.lit("No Shift").alias("Shift"))
    result_df = (
        df_filtered.group_by(["Week", "IEX ID", "Name", "TL", "LOB", "Shift"])
                   .agg(pl.count().alias("Count"))
                   .sort(by=["Week", "IEX ID", "Name", "TL", "LOB", "Count"], 
                         descending=[False, False, False, False, False, True])
                   .filter(pl.col("Count") == pl.col("Count").max().over(["Week", "IEX ID", "Name", "TL", "LOB"]))
                   .drop("Count")
    )
    return result_df

# %% [markdown]
# ## Step 7 — load_schedule_of_schedule() and combine team/VN sources
#
# - Load all files via input_data(), then apply get_most_frequent_shift().
# - Convert to pandas for process_schedule_shift(), coerce 'IEX ID' numeric.
# - Append per source (Schedule_Team vs VN_Team), then concatenate.
# - Export per-Week Excel snapshots into the analysis folder for inspection.

# %%
# Step 7 — load_schedule_of_schedule() and combine team/VN sources
# - Load all files via input_data(), then apply get_most_frequent_shift().
# - Convert to pandas for process_schedule_shift(), coerce 'IEX ID' numeric.
# - Append per source (Schedule_Team vs VN_Team), then concatenate.
# - Export per-Week Excel snapshots into the analysis folder for inspection.
# ---

def load_schedule_of_schedule(folder_path):
    all_schedules = []

    schedule_df = input_data(folder_path)
    schedule_df = get_most_frequent_shift(schedule_df)

    if schedule_df.height > 0:
        schedule_df = schedule_df.to_pandas()
        schedule_df = process_schedule_shift(schedule_df, "Shift")
        schedule_df['IEX ID'] = pd.to_numeric(schedule_df['IEX ID'], errors='coerce')
        all_schedules.append(schedule_df)

    return pd.concat(all_schedules, ignore_index=True) if all_schedules else pd.DataFrame()

Schedule_Of_Schedule_Team = load_schedule_of_schedule(folder_paths["schedule_team"])
Schedule_Of_Schedule_Team['Source'] = "Schedule_Team"

Schedule_Of_Schedule_VN = load_schedule_of_schedule(folder_paths["schedule_vn"])
Schedule_Of_Schedule_VN['Source'] = "VN_Team"

Combine_Schedule = pd.concat([Schedule_Of_Schedule_Team,Schedule_Of_Schedule_VN])

for week_col, group in Combine_Schedule.groupby('Week'):
    
    file_name = os.path.join(folder_paths['analysis'], f"{week_col}.xlsx")
    group.to_excel(file_name, sheet_name=str(week_col), index=False)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9052\1872155603.py:31: DeprecationWarning: `DataFrame.melt` is deprecated; use `DataFrame.unpivot` instead, with `index` instead of `id_vars` and `on` instead of `value_vars`
#   df = df.melt(id_vars=cols_to_choose, variable_name="Date", value_name="Shift")
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9052\1918670955.py:16: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   .agg(pl.count().alias("Count"))
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9052\1872155603.py:31: DeprecationWarning: `DataFrame.melt` is deprecated; use `DataFrame.unpivot` instead, with `index` instead of `id_vars` and `on` instead of `value_vars`
#   df = df.melt(id_vars=cols_to_choose, variable_name="Date", value_name="Shift")
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9052\1918670955.py:16: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# ...

# %% [markdown]
# ## Step 8 — Swap analysis with NetworkX
#
# - Read the selected week's schedule and the 'Swap' sheet from the VN team workbook.
# - Map weekdays to actual dates (based on the 'week' string).
# - Build an undirected graph of IEX swaps using NetworkX; group connected components.
# - Create 'Detailed Swap History' and 'Swap Steps' for each IEX based on edges and steps.
# - Attach these summaries to Schedule_VN for downstream reporting.

# %%
# Step 8 — Swap analysis with NetworkX
# - Read the selected week's schedule and the 'Swap' sheet from the VN team workbook.
# - Map weekdays to actual dates (based on the 'week' string).
# - Apply swaps SEQUENTIALLY from top-to-bottom so repeated swaps on the same IEX are honored.
# - Build an undirected graph of IEX swaps using NetworkX (optional context).
# - Create 'Detailed Swap History' IN TOP-TO-BOTTOM ORDER and 'Swap Steps' per IEX.
# - Attach these summaries to Schedule_VN for downstream reporting.
# ---

schedule_step_1 = pd.read_excel(f"{folder_paths['schedule_team']}/{week}.xlsx")
schedule_step_1['Week'] = week
cols = ['Week'] + [col for col in schedule_step_1.columns if col != 'Week']
Schedule_VN = schedule_step_1[cols]

original_path = folder_paths['vn_team']
temp_path = os.path.join(tempfile.gettempdir(), "temp_schedule.xlsx")

shutil.copy2(original_path, temp_path)

Schedule_Swap = pd.read_excel(temp_path, sheet_name="Swap", header=None)
Schedule_Swap.columns = Schedule_Swap.iloc[0]
Schedule_Swap = Schedule_Swap.iloc[1:].reset_index(drop=True)
os.remove(temp_path)
    
Schedule_Swap = Schedule_Swap[Schedule_Swap['Week'] == week]

# Ensure numeric types for reliable matching
Schedule_VN["IEX ID"] = pd.to_numeric(Schedule_VN["IEX ID"], errors="coerce")
for _c in ["IEX1", "IEX2"]:
    if _c in Schedule_Swap.columns:
        Schedule_Swap[_c] = pd.to_numeric(Schedule_Swap[_c], errors="coerce")

columns_to_select = ['Week', 'IEX1', 'IEX2','Name1','Name2','Step', 
                     'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
Schedule_Swap = Schedule_Swap[columns_to_select]

week_start_date = datetime.strptime(week.replace("Schedule_", ""), "%Y_%m_%d")
day_mapping = {
    "Monday": (week_start_date + timedelta(days=0)).strftime("%Y-%m-%d"),
    "Tuesday": (week_start_date + timedelta(days=1)).strftime("%Y-%m-%d"),
    "Wednesday": (week_start_date + timedelta(days=2)).strftime("%Y-%m-%d"),
    "Thursday": (week_start_date + timedelta(days=3)).strftime("%Y-%m-%d"),
    "Friday": (week_start_date + timedelta(days=4)).strftime("%Y-%m-%d"),
    "Saturday": (week_start_date + timedelta(days=5)).strftime("%Y-%m-%d"),
    "Sunday": (week_start_date + timedelta(days=6)).strftime("%Y-%m-%d"),
}
day_abbr = {
    "Monday": "Mon", 
    "Tuesday": "Tue", 
    "Wednesday": "Wed",
    "Thursday": "Thu", 
    "Friday": "Fri", 
    "Saturday": "Sat", 
    "Sunday": "Sun"
}

def swap_shift(schedule_df, iex1, iex2, day_col):
    """
    Swap values between two rows (identified by IEX IDs) in a single day column.
    - Skips gracefully if either agent is missing.
    - Returns the updated DataFrame.
    """
    # Defensive: ensure numeric IEX ID
    if not pd.api.types.is_integer_dtype(schedule_df["IEX ID"]):
        schedule_df["IEX ID"] = pd.to_numeric(schedule_df["IEX ID"], errors="coerce")

    idx1 = schedule_df.index[schedule_df["IEX ID"] == pd.to_numeric(iex1, errors="coerce")].tolist()
    idx2 = schedule_df.index[schedule_df["IEX ID"] == pd.to_numeric(iex2, errors="coerce")].tolist()
    if not idx1 or not idx2:
        print(f"[warn] Could not find IEX ID {iex1} or {iex2} in Schedule_VN")
        return schedule_df
    idx1 = idx1[0]
    idx2 = idx2[0]

    v1 = schedule_df.at[idx1, day_col]
    v2 = schedule_df.at[idx2, day_col]

    schedule_df.at[idx1, day_col] = v2
    schedule_df.at[idx2, day_col] = v1

    print(f"[swap] {day_col}: {iex1} ↔ {iex2}")
    return schedule_df

# =========================================
# APPLY SWAPS SEQUENTIALLY, TOP-TO-BOTTOM
# =========================================
weekdays = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]

# Preserve the visual order from the sheet
Schedule_Swap = Schedule_Swap.reset_index(drop=True)
Schedule_Swap["_row_order_"] = Schedule_Swap.index

for _, row in Schedule_Swap.sort_values("_row_order_").iterrows():
    iex1, iex2 = row["IEX1"], row["IEX2"]

    if iex1 == iex2:
        # Self-change: write provided value to the agent's cell for that weekday
        for day in weekdays:
            val = row.get(day, "")
            if pd.isna(val):
                continue
            sval = str(val).strip()
            # ignore empty / KEEP / SWAP markers here
            if sval == "" or sval.upper() in {"KEEP", "SWAP"}:
                continue
            date_col = day_mapping[day]
            if date_col not in Schedule_VN.columns:
                print(f"[warn] Day column not found: {day} -> {date_col}")
                continue
            Schedule_VN.loc[Schedule_VN["IEX ID"] == iex1, date_col] = sval
            print(f"[move] {day} ({date_col}): {iex1} -> '{sval}'")
    else:
        # Pair swap: only act on cells marked 'SWAP' (case-insensitive)
        for day in weekdays:
            flag = str(row.get(day, "")).strip().upper()
            if flag != "SWAP":
                continue
            date_col = day_mapping[day]
            if date_col not in Schedule_VN.columns:
                print(f"[warn] Day column not found: {day} -> {date_col}")
                continue
            Schedule_VN = swap_shift(Schedule_VN, iex1, iex2, date_col)

# =========================================
# BUILD GRAPH & DETAILED HISTORY — COMPONENT-WIDE, TOP-TO-BOTTOM
# =========================================
from collections import defaultdict

# 1) Build graph: include all IEX (also isolated self-change rows)
G = nx.Graph()
all_agents = set()

for _, row in Schedule_Swap.iterrows():
    iex1, iex2 = row["IEX1"], row["IEX2"]
    if pd.notna(iex1): all_agents.add(int(iex1))
    if pd.notna(iex2): all_agents.add(int(iex2))
    if pd.notna(iex1) and pd.notna(iex2) and iex1 != iex2:
        G.add_edge(int(iex1), int(iex2))

for a in all_agents:
    G.add_node(int(a))  # ensure isolated nodes are present

# 2) Map each agent to its connected component id
components = list(nx.connected_components(G))
agent_to_comp = {}
for i, comp in enumerate(components):
    for a in comp:
        agent_to_comp[int(a)] = i

# 3) Build component-level lines IN SHEET ORDER (top-to-bottom)
comp_lines = defaultdict(list)   # comp_id -> ordered list of lines
comp_seen  = defaultdict(set)    # comp_id -> set for dedupe
iex_steps  = defaultdict(set)    # per-agent set of steps (keep as before)

weekdays = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]

for _, row in Schedule_Swap.sort_values("_row_order_").iterrows():
    iex1, iex2 = row["IEX1"], row["IEX2"]
    name1, name2 = str(row.get("Name1","") or ""), str(row.get("Name2","") or "")
    step = str(row.get("Step","") or "").strip()

    # collect per-agent steps (same behavior as before)
    if pd.notna(iex1) and step:
        iex_steps[int(iex1)].add(step)
    if pd.notna(iex2) and step:
        iex_steps[int(iex2)].add(step)

    # build day suffix from flags in THIS row
    swap_days = [d for d in weekdays if str(row.get(d, "")).strip().upper() == "SWAP"]
    if len(swap_days) == 7 or len(swap_days) == 0:
        day_str = ""
    else:
        day_str = " (Swap " + ", ".join(day_abbr[d] for d in swap_days) + ")"

    if pd.notna(iex1) and (pd.isna(iex2) or iex1 == iex2):
        # self-change line (single agent)
        agent = int(iex1)
        comp_id = agent_to_comp.get(agent, None)
        line = f"{agent} - {name1} moved to new shift (Step {step})"
        if comp_id is not None and line not in comp_seen[comp_id]:
            comp_lines[comp_id].append(line)
            comp_seen[comp_id].add(line)
    elif pd.notna(iex1) and pd.notna(iex2) and iex1 != iex2:
        # pair swap line (belongs to the component containing the pair)
        a, b = int(iex1), int(iex2)
        comp_id = agent_to_comp.get(a, agent_to_comp.get(b, None))
        line = f"{a} - {name1} <-> {b} - {name2}{day_str} (Step {step})"
        if comp_id is not None and line not in comp_seen[comp_id]:
            comp_lines[comp_id].append(line)
            comp_seen[comp_id].add(line)

# 4) Assign the SAME history (component-wide) to every agent in that component
detailed_by_agent = {}
for a in all_agents:
    comp_id = agent_to_comp.get(int(a), None)
    if comp_id is None:
        detailed_by_agent[int(a)] = ""
    else:
        detailed_by_agent[int(a)] = "\n".join(comp_lines[comp_id])

# 5) Map back to Schedule_VN
Schedule_VN["Detailed Swap History"] = Schedule_VN["IEX ID"].map(
    lambda x: detailed_by_agent.get(int(x), "") if pd.notna(x) else ""
).fillna("")

# Keep per-agent steps (sorted numerically as before)
Schedule_VN["Swap Steps"] = Schedule_VN["IEX ID"].map(
    lambda x: ", ".join(sorted({s for s in iex_steps.get(int(x), set()) if s}, key=int)) if pd.notna(x) else ""
).fillna("")

# Debug filter (unchanged)
schedule_step_1[(schedule_step_1['Week'] == 'Schedule_2025_06_09') & (schedule_step_1['IEX ID'] == 3092416)]
# Out:
# [swap] 2026-05-05: 3110171 ↔ 3052306
# [swap] 2026-05-10: 3110171 ↔ 3052306
# [swap] 2026-05-08: 3109357 ↔ 3014817
# [swap] 2026-05-10: 3109357 ↔ 3014817
# [swap] 2026-05-08: 3089101 ↔ 3026476
# [swap] 2026-05-10: 3089101 ↔ 3026476
# [move] Monday (2026-05-04): 3003446 -> '2000-0500'
# [move] Tuesday (2026-05-05): 3003446 -> '2000-0500'
# [move] Wednesday (2026-05-06): 3003446 -> '2000-0500'
# [move] Thursday (2026-05-07): 3003446 -> '2000-0500'
# [move] Friday (2026-05-08): 3003446 -> 'OFF'
# [move] Saturday (2026-05-09): 3003446 -> '2000-0500'
# [move] Sunday (2026-05-10): 3003446 -> '2000-0500'
# [swap] 2026-05-06: 3085545 ↔ 3090805
# [swap] 2026-05-07: 3085545 ↔ 3090805
# [swap] 2026-05-08: 3085545 ↔ 3090805
# [swap] 2026-05-09: 3085545 ↔ 3090805
# [swap] 2026-05-04: 3092314 ↔ 3089175
# [swap] 2026-05-05: 3092314 ↔ 3089175
# [swap] 2026-05-06: 3092314 ↔ 3089175
# [swap] 2026-05-07: 3092314 ↔ 3089175
# [swap] 2026-05-08: 3092314 ↔ 3089175
# [swap] 2026-05-09: 3092314 ↔ 3089175
# ...

# %% [markdown]
# ## Step 9 — Debug query
#
# - A quick filter to inspect a specific agent/week combination for validation.

# %%
# Step 9 — Debug query
# - A quick filter to inspect a specific agent/week combination for validation.
# ---

Schedule_VN[(schedule_step_1['Week'] == 'Schedule_2025_06_09') & (schedule_step_1['IEX ID'] == 3092416)]
# Out:
# Empty DataFrame
# Columns: [Week, IEX ID, Name, TL, Status, Sec Status, LOB, 2026-05-04, 2026-05-05, 2026-05-06, 2026-05-07, 2026-05-08, 2026-05-09, 2026-05-10, Detailed Swap History, Swap Steps]
# Index: []

# %% [markdown]
# ## Step 10 — Debug query (duplicate)
#
# - Same as Step 9; likely used during iterative development for display/testing.

# %%
# Step 10 — Debug query (duplicate)
# - Same as Step 9; likely used during iterative development for display/testing.
# ---

Schedule_VN[(schedule_step_1['Week'] == 'Schedule_2025_06_09') & (schedule_step_1['IEX ID'] == 3092416)]
# Out:
# Empty DataFrame
# Columns: [Week, IEX ID, Name, TL, Status, Sec Status, LOB, 2026-05-04, 2026-05-05, 2026-05-06, 2026-05-07, 2026-05-08, 2026-05-09, 2026-05-10, Detailed Swap History, Swap Steps]
# Index: []

# %% [markdown]
# ## Step 11 — Debug query (duplicate)
#
# - Same as Step 9; repeated debugging convenience cell.

# %%
# Step 11 — Debug query (duplicate)
# - Same as Step 9; repeated debugging convenience cell.
# ---

Schedule_VN[(schedule_step_1['Week'] == 'Schedule_2025_06_09') & (schedule_step_1['IEX ID'] == 3092416)]
# Out:
# Empty DataFrame
# Columns: [Week, IEX ID, Name, TL, Status, Sec Status, LOB, 2026-05-04, 2026-05-05, 2026-05-06, 2026-05-07, 2026-05-08, 2026-05-09, 2026-05-10, Detailed Swap History, Swap Steps]
# Index: []

# %% [markdown]
# ## Step 12 — Merge Planned leave and normalize codes; export SCHEDULE_STEP_1
#
# - Add 'Planned Note' column to Schedule_VN.
# - Read 'Planned' sheet, standardize headers, and align 'Leave Date' with weekday columns.
# - Write notes and mark leave for matching agent/date cells.
# - Normalize codes: PTO→AL, 'Paid Leave'→CO; compute total 'Planned' days per agent.
# - Update Week and export to the step-1 output folder as '{week}.xlsx'.

# %%
# Step 12 — Merge Planned leave and normalize codes; export SCHEDULE_STEP_1
# - Add 'Planned Note' column to Schedule_VN.
# - Read 'Planned' sheet, standardize headers, and align 'Leave Date' with weekday columns.
# - AUDIT STEP: Cross-check between Global Schedule and Local Planned list for the CURRENT week only.
# - Write notes and mark leave for matching agent/date cells.
# - Normalize codes: PTO->AL, 'Paid Leave'->CO; compute total 'Planned' days per agent.
# - Update Week and export to the step-1 output folder as '{week}.xlsx'.
# ---

Schedule_VN['Planned Note'] = ""

temp_path = os.path.join(tempfile.gettempdir(), "temp_planned.xlsx")
shutil.copy2(folder_paths['vn_team'], temp_path)
Schedule_Planned = pd.read_excel(temp_path, sheet_name="Planned", header=None)
os.remove(temp_path)

Schedule_Planned.columns = Schedule_Planned.iloc[0]
Schedule_Planned = Schedule_Planned[1:].reset_index(drop=True)
Schedule_Planned = Schedule_Planned[['Leave Date', 'Week','Type of Request', 'IEX ID', 'Agent Name','Planned']]
Schedule_Planned['Leave Date'] = pd.to_datetime(Schedule_Planned['Leave Date'])
Schedule_Planned['Leave Date'] = Schedule_Planned['Leave Date'].astype(str)

# ==============================================================================
# START: AUDIT PLANNED LEAVE GLOBAL vs LOCAL (CURRENT WEEK ONLY)
# ==============================================================================
print("\n🔍 CROSS-CHECKING PLANNED LEAVE BETWEEN GLOBAL SCHEDULE AND LOCAL LIST...")

# 1. Extract dates for the current processing week
date_cols = [str(col) for col in Schedule_VN.columns if str(col).startswith('202')]
leave_codes_global = ['PTO', 'AL', 'PAID LEAVE', 'CO', 'HOLIDAY', 'HO', 'LWP']
global_leaves = []

# Extract leaves from Global Schedule
for idx, row in Schedule_VN.iterrows():
    iex = row['IEX ID']
    name = row.get('Name', '')
    for d in date_cols:
        val = str(row[d]).strip().upper()
        if val in leave_codes_global:
            global_leaves.append({
                'IEX ID': pd.to_numeric(iex, errors='coerce'),
                'Name': name,
                'Date': str(d),
                'Global_Code': val
            })
df_global_leaves = pd.DataFrame(global_leaves)

# 2. Prepare Local leave list and FILTER BY CURRENT WEEK'S DATES
df_local_leaves = Schedule_Planned[['IEX ID', 'Agent Name', 'Leave Date', 'Type of Request']].copy()
df_local_leaves.rename(columns={'Leave Date': 'Date', 'Type of Request': 'Local_Code', 'Agent Name': 'Name_local'}, inplace=True)
df_local_leaves['IEX ID'] = pd.to_numeric(df_local_leaves['IEX ID'], errors='coerce')

# FILTER: Keep only records that fall within the current week's dates
df_local_leaves = df_local_leaves[df_local_leaves['Date'].isin(date_cols)]

# 3. Merge both tables for two-way comparison (Outer Join)
if df_global_leaves.empty:
    df_global_leaves = pd.DataFrame(columns=['IEX ID', 'Name', 'Date', 'Global_Code'])
    
merged_leaves = pd.merge(df_local_leaves, df_global_leaves, on=['IEX ID', 'Date'], how='outer')

# 4. Analyze Discrepancies
discrepancies = []
# Normalization map to check for mismatched codes (e.g., Local requests Paid Leave but Global enters PTO)
norm_map = {'PTO': 'AL', 'AL': 'AL', 'PAID LEAVE': 'CO', 'CO': 'CO', 'HOLIDAY': 'HO', 'HO': 'HO', 'LWP': 'LWP'}

for _, row in merged_leaves.iterrows():
    iex = row['IEX ID']
    date = row['Date']
    l_code_raw = str(row['Local_Code']).strip().upper()
    g_code_raw = str(row['Global_Code']).strip().upper()
    
    is_local_empty = pd.isna(row['Local_Code']) or l_code_raw == 'NAN' or l_code_raw == ''
    is_global_empty = pd.isna(row['Global_Code']) or g_code_raw == 'NAN' or g_code_raw == ''
    
    name = row['Name_local'] if pd.notna(row.get('Name_local')) else row.get('Name', '')
    
    # Scenario 1: Global filled leave, but Local did not request it
    if is_local_empty and not is_global_empty:
        discrepancies.append({
            'IEX ID': iex, 'Name': name, 'Date': date,
            'Local Request': 'Not in list', 'Global Schedule': g_code_raw,
            'Issue': 'Global filled Leave (Not in Planned list)'
        })
    # Scenario 2: Local requested leave, but Global did not fill it / scheduled a shift
    elif not is_local_empty and is_global_empty:
        actual_global_shift = "No data"
        if date in Schedule_VN.columns:
            mask = Schedule_VN['IEX ID'] == iex
            if not Schedule_VN.loc[mask, date].empty:
                actual_global_shift = Schedule_VN.loc[mask, date].iloc[0]
                
        discrepancies.append({
            'IEX ID': iex, 'Name': name, 'Date': date,
            'Local Request': l_code_raw, 'Global Schedule': actual_global_shift,
            'Issue': 'Global missed / Scheduled over leave'
        })
    # Scenario 3: Both have leave, but the code mismatches (e.g., AL vs CO)
    elif not is_local_empty and not is_global_empty:
        if norm_map.get(l_code_raw, l_code_raw) != norm_map.get(g_code_raw, g_code_raw):
            discrepancies.append({
                'IEX ID': iex, 'Name': name, 'Date': date,
                'Local Request': l_code_raw, 'Global Schedule': g_code_raw,
                'Issue': 'Mismatched Leave Code'
            })

df_discrepancies = pd.DataFrame(discrepancies)

if not df_discrepancies.empty:
    print(f"⚠️ WARNING: Found {len(df_discrepancies)} discrepancies between Local Planned list and Global Schedule!")
    # Output raw dataframe without color styling
    display(df_discrepancies)
else:
    print("✅ EXCELLENT: Global Schedule perfectly matches the Local Planned Leave list!")
print("="*80 + "\n")
# ==============================================================================
# END OF AUDIT STEP
# ==============================================================================


# Overwrite Planned Note & modify Schedule_VN based on the Local list
for _, row in Schedule_Planned.iterrows():
    col_name = row['Leave Date']
    iex = row['IEX ID']
    req = row['Type of Request']
    name = row['Agent Name']

    if col_name in Schedule_VN.columns:
        mask = Schedule_VN['IEX ID'] == iex
        
        if not Schedule_VN.loc[mask, col_name].empty and Schedule_VN.loc[mask, col_name].iloc[0] != "OFF":
            Schedule_VN.loc[mask, col_name] = req
            Schedule_VN.loc[mask, 'Planned'] = "RTA"
        else:
            if Schedule_VN.loc[mask, 'Planned Note'].empty:
                existing_note = ""
            else:
                existing_note = Schedule_VN.loc[mask, 'Planned Note'].iloc[0]
            new_note = f"{iex} - {name} has {req} on OFF date {col_name}"
            
            if pd.isna(existing_note) or existing_note == "":
                Schedule_VN.loc[mask, 'Planned Note'] = new_note
            else:
                Schedule_VN.loc[mask, 'Planned Note'] = existing_note + " | " + new_note
    else:
        # Ignore historical records that don't belong to the current week
        pass

cols_to_check = Schedule_VN.columns[7:14]

Schedule_VN['Planned'] = Schedule_VN[cols_to_check].apply(lambda x: (x == 'AL').sum() + (x == 'CO').sum() + (x == 'HO').sum(), axis=1)

Schedule_VN['Week'] = week
columns_to_replace = Schedule_VN.columns[6:]
Schedule_VN[columns_to_replace] = Schedule_VN[columns_to_replace].replace({'PTO': 'AL','Paid Leave': 'CO','Holiday':'HO'})
Schedule_VN['Planned'] = Schedule_VN[cols_to_check].apply(lambda x: x[x.str.contains('AL|CO|HO', na=False)].count(), axis=1)

file_path = os.path.join(folder_paths['schedule_step_1'], week + ".xlsx")

output_path = f"{folder_paths['schedule_step_1']}/{week}.xlsx"
Schedule_VN.to_excel(output_path, index=False)
print(f"\n[COMPLETED] Planned Leave processing finished and file saved to: {output_path}")
# Out:
# 🔍 CROSS-CHECKING PLANNED LEAVE BETWEEN GLOBAL SCHEDULE AND LOCAL LIST...
# ⚠️ WARNING: Found 10 discrepancies between Local Planned list and Global Schedule!
#     IEX ID                    Name        Date Local Request Global Schedule  \
# 0  3005527           PHAM THANH VU  2026-05-06            CO       0600-1500
# 1  3052243        VO TRAN HIEN MAI  2026-05-04            CO             PTO
# 2  3052243        VO TRAN HIEN MAI  2026-05-05            CO             PTO
# 3  3085545              DOAN AN NY  2026-05-10            AL       0600-1500
# 4  3089155           VUU TIEN NHAN  2026-05-10            CO       0600-1500
# 5  3090805           LE THUY TRIEU  2026-05-10            CO       0600-1500
# 6  3091504           VU MINH NGHIA  2026-05-07            CO       0600-1500
# 7  3092350  NGUYEN QUYNH TUYET KHA  2026-05-09            CO       0700-1600
# 8  3109357              VO DUC HUY  2026-05-08            CO       0700-1600
# ...

# %%
def process_historical_swap_v3(file_path, sheet_name="Step_2"):
    temp_path = os.path.join(tempfile.gettempdir(), "temp_historical_swap.xlsx")
    shutil.copy2(file_path, temp_path)
    df = pd.read_excel(temp_path, sheet_name=sheet_name)
    os.remove(temp_path)
    days_short = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
    days_full = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    results = []
    for i in range(0, len(df) - 1, 2):
        agent1 = df.iloc[i]
        agent2 = df.iloc[i+1]
        row_data = {
            'IEX1': agent1['IEX'],
            'IEX2': agent2['IEX'],
            'Name1': agent1['Agent Name'],
            'Name2': agent2['Agent Name'],
            'Step': 2 
        }
        old_a1 = [str(agent1[f"Old {d}"]).strip().upper() for d in days_short]
        new_a1 = [str(agent1[f"New {d}"]).strip().upper() for d in days_short]
        old_a2 = [str(agent2[f"Old {d}"]).strip().upper() for d in days_short]
        new_a2 = [str(agent2[f"New {d}"]).strip().upper() for d in days_short]
        is_full_swap = (new_a1 == old_a2) and (new_a2 == old_a1)
        swapped_days_list = []
        for j, (short_day, full_day) in enumerate(zip(days_short, days_full)):
            if is_full_swap:
                row_data[full_day] = "SWAP"
                swapped_days_list.append(short_day)
            else:
                if old_a1[j] != new_a1[j] or old_a2[j] != new_a2[j]:
                    row_data[full_day] = "SWAP"
                    swapped_days_list.append(short_day)
                else:
                    row_data[full_day] = "KEEP"
        if is_full_swap or len(swapped_days_list) == 7:
            row_data['Swap Days'] = 'Full'
        elif len(swapped_days_list) > 0:
            row_data['Swap Days'] = ', '.join(swapped_days_list)
        else:
            row_data['Swap Days'] = 'None'
        results.append(row_data)
    return pd.DataFrame(results)

input_path = folder_paths["vn_team"]
# output_path = f'{first_glob}/Concentrix Corporation/WFM-Expedia-HCM - Branding files/Schedule/Historical_Swap_Final.xlsx'
df_result = process_historical_swap_v3(input_path, sheet_name="Step_2")
# df_result.to_excel(output_path, index=False)
print("Processing successful! The file has been saved at:", output_path)
df_result
# Out:
# Processing successful! The file has been saved at: C:/Users/ADMIN/Concentrix Corporation/WFM-Expedia-HCM - Branding files/Rawdata/INPUT_SCHEDULE/SCHEDULE_STEP_1/Schedule_2026_05_04.xlsx
#        IEX1     IEX2                 Name1                 Name2  Step Monday  \
# 0   3052243  3096798      VO TRAN HIEN MAI     TRAN THI BICH LOI     2   KEEP
# 1   3026462  3002199           VO TIEN DAT      LE HOANG MAI THY     2   KEEP
# 2   3096723  3097284   HO NGOC HUYEN TRANG      NGUYEN MINH NHAT     2   KEEP
# 3   3089163  3084770      DUONG CONG HOANG               K’ SONH     2   SWAP
# 4   3089861  3085344  NGUYEN HA TUAN THIEN  NGUYEN LE NGOC KHANH     2   SWAP
# 5   3109551  3109399         HOANG DAI HAI   NGUYEN THI KIM NGAN     2   SWAP
# 6   3109399  3109643   NGUYEN THI KIM NGAN          TRAN DUC TIN     2   KEEP
# 7   3109551  3109290         HOANG DAI HAI         TRAN PHI LINH     2   KEEP
# 8   3052306  3085158          BUI BA DUONG          TA KHANH HOA     2   SWAP
# ...

# %%
def get_cell_style(val):
    if pd.isna(val) or str(val).strip() == "":
        return ""
    
    v = str(val).strip().upper()
    
    if v == "OFF":
        return "background-color: #A6A6A6; color: black;"
    elif v == "AL":
        return "background-color: #A9D08E; color: black;"
    elif v == "CO":
        return "background-color: #8EA9DB; color: black;"
    elif v == "LWP":
        return "background-color: #F4B084; color: black;"
    elif "TERMINATION" in v:
        return "background-color: #FF0000; color: white;"
    elif v == "HO":
        return "background-color: #FFD966; color: black;"
    
    v_clean = v.replace(':', '')
    if '-' in v_clean:
        start_str = v_clean.split('-')[0].strip()
        if start_str.isdigit():
            start_time = int(start_str)
            if 500 <= start_time < 1200:
                return "background-color: #9BC2E6; color: black;"
            elif 1200 <= start_time < 1800:
                return "background-color: #FFE699; color: black;"
            else:
                return "background-color: #CCC0DA; color: black;"
    return ""

def merge_schedules_horizontally(base_folder, output_file="Master_Schedule_Merged.xlsx"):
    base_path = Path(base_folder)
    file_list = [f for f in base_path.rglob("*Schedule_WB*.xlsx") if not f.name.startswith("~$")]
   
    print(f"Found {len(file_list)} Schedule files. Starting automatic scan...\n")
    print("-" * 60)
   
    fixed_cols = ['IEX ID', 'OracleID', 'Email', 'Employee Name']
    master_df = None
   
    for file in file_list:
        temp_path = os.path.join(tempfile.gettempdir(), f"temp_{file.name}")
        shutil.copy2(file, temp_path)
       
        try:
            with pd.ExcelFile(temp_path) as xls:
                wb_sheet = next((s for s in xls.sheet_names if s.upper().startswith("WB")), None)
                if not wb_sheet:
                    wb_sheet = next((s for s in ["Schedule_FINAL", "Schedule_VN"] if s in xls.sheet_names), None)
               
                sheets_to_process = [s for s in [wb_sheet, "Hierarchy"] if s and s in xls.sheet_names]
                if not sheets_to_process: 
                    continue
                    
                for sheet_name in sheets_to_process:
                    df_raw = pd.read_excel(xls, sheet_name=sheet_name, header=None)
                    header_row = -1
                    for idx, row in df_raw.head(20).iterrows():
                        row_strs = [str(x).strip().upper() for x in row.values if pd.notna(x)]
                        if any(k in x for x in row_strs for k in ["IEX ID", "EMP ID", "ORACLE"]):
                            header_row = idx
                            break
                   
                    if header_row == -1: continue
                        
                    df = pd.read_excel(xls, sheet_name=sheet_name, header=header_row)
                    df.rename(columns=lambda x: str(x).strip(), inplace=True)
                    
                    if sheet_name == "Hierarchy":
                        df.rename(columns={'Emp ID': 'OracleID', 'Name': 'Employee Name'}, inplace=True)
                        df['IEX ID'] = pd.NA
                        df['Email'] = ""
                    else:
                        df.rename(columns={'Email Id': 'Email', 'Email ID': 'Email', 'Name': 'Employee Name'}, inplace=True)
                    
                    df['OracleID'] = pd.to_numeric(df['OracleID'], errors='coerce')
                    df = df.dropna(subset=['OracleID']).copy()
                   
                    date_rename = {}
                    cols_to_keep = [c for c in fixed_cols if c in df.columns]
                    for col in df.columns:
                        if col not in fixed_cols:
                            try:
                                dt = pd.to_datetime(col)
                                date_rename[col] = dt.strftime('%Y-%m-%d')
                                cols_to_keep.append(col)
                            except:
                                pass
                   
                    df = df[cols_to_keep].copy()
                    df.rename(columns=date_rename, inplace=True)
                   
                    if sheet_name == "Hierarchy":
                        date_cols_h = [date_rename[c] for c in date_rename]
                        df[date_cols_h] = df[date_cols_h].replace("WO", "OFF")
                        df[date_cols_h] = df[date_cols_h].replace(["0", "nan", "", np.nan], "EMPTY_H")
                    
                    df.set_index('OracleID', inplace=True)
                    master_df = df if master_df is None else master_df.combine_first(df)
               
                print(f"[+] MERGED SUCCESSFULLY: {file.name}")
                
        except Exception as e:
            print(f"[!] ERROR with file {file.name}: {e}")
        finally:
            if os.path.exists(temp_path):
                try: os.remove(temp_path)
                except: pass

    if master_df is None or master_df.empty: 
        print("No data to merge!")
        return None
   
    master_df.reset_index(inplace=True)
    master_df['IEX ID'] = pd.to_numeric(master_df['IEX ID'], errors='coerce')
    master_df['OracleID'] = pd.to_numeric(master_df['OracleID'], errors='coerce')
   
    master_df['is_h'] = master_df['IEX ID'].isna()
    master_df = master_df.sort_values(['is_h', 'OracleID'], ascending=[True, True]).drop(columns=['is_h'])
   
    date_cols = sorted([c for c in master_df.columns if c not in fixed_cols], key=lambda x: pd.to_datetime(x))
    master_df = master_df[fixed_cols + date_cols]

    TERMINATION_GAP_THRESHOLD = 7
    
    df_dates = master_df[date_cols].copy()
    
    df_dates = df_dates.replace(r'^\s*$', np.nan, regex=True).replace(["nan", "EMPTY_H"], np.nan)
    term_mask = df_dates.apply(lambda s: s.astype(str).str.contains('TERMINATION', case=False, na=False))
    df_dates[term_mask] = "Termination"

    ffilled = df_dates.ffill(axis=1)
    mask_to_update = (ffilled == "Termination") & df_dates.isna()
    df_dates[mask_to_update] = "Termination"

    is_valid = df_dates.notna() & (df_dates != "Termination")
    col_indices = np.arange(len(date_cols))
    
    first_valid_idx = np.where(is_valid, col_indices, len(date_cols)).min(axis=1)
    col_idx_2d = np.tile(col_indices, (len(df_dates), 1))
    mask_leading = col_idx_2d < first_valid_idx[:, None]
    
    valid_indices = np.where(is_valid, col_indices, -1)
    last_valid_idx = valid_indices.max(axis=1)
    
    trailing_blanks = len(date_cols) - 1 - last_valid_idx
    rows_to_update = (trailing_blanks >= TERMINATION_GAP_THRESHOLD) & (last_valid_idx >= 0)
    
    mask_trailing = (col_idx_2d > last_valid_idx[:, None]) & rows_to_update[:, None]
    
    df_dates.values[mask_trailing] = "Termination"
    df_dates.values[mask_leading] = ""

    is_inactive = (df_dates == "Termination").any(axis=1)
    status_list = np.where(is_inactive, "Inactive", "Active")
    master_df.insert(master_df.columns.get_loc('Employee Name') + 1, 'Status', status_list)

    master_df[date_cols] = df_dates
    is_mgr = master_df['IEX ID'].isna()
    master_df.loc[~is_mgr, date_cols] = master_df.loc[~is_mgr, date_cols].fillna("OFF")
    master_df.loc[is_mgr, date_cols] = master_df.loc[is_mgr, date_cols].fillna("")

    master_df = master_df.dropna(subset=['OracleID', 'Employee Name'])

    styler = master_df.style
    if hasattr(styler, 'map'):
        styled_df = styler.map(get_cell_style, subset=date_cols)
    else:
        styled_df = styler.applymap(get_cell_style, subset=date_cols)

    output_path = base_path / output_file
    styled_df.to_excel(output_path, index=False, engine='openpyxl')
   
    print(f"\n[COMPLETED] Master file saved at: {output_path}")
    return master_df

base_dir = f'{first_glob}/Concentrix Corporation/WFM-Expedia-HCM - Branding files/Schedule/Schedule (Ops version)/2026'
df_result = merge_schedules_horizontally(base_dir)
df_result
# Out:
# Found 18 Schedule files. Starting automatic scan...
#
# ------------------------------------------------------------
# [+] MERGED SUCCESSFULLY: Expedia VN_Schedule_WB0105.xlsx
# [+] MERGED SUCCESSFULLY: Expedia VN_Schedule_WB0112.xlsx
# [+] MERGED SUCCESSFULLY: Expedia VN_Schedule_WB0119.xlsx
# [+] MERGED SUCCESSFULLY: Expedia VN_Schedule_WB0126.xlsx
# [+] MERGED SUCCESSFULLY: Expedia VN_Schedule_WB0202.xlsx
# [+] MERGED SUCCESSFULLY: Expedia VN_Schedule_WB0209.xlsx
# [+] MERGED SUCCESSFULLY: Expedia VN_Schedule_WB0216.xlsx
# [+] MERGED SUCCESSFULLY: Expedia VN_Schedule_WB0223.xlsx
# [+] MERGED SUCCESSFULLY: Expedia VN_Schedule_WB0302.xlsx
# [+] MERGED SUCCESSFULLY: Expedia VN_Schedule_WB0309.xlsx
# [+] MERGED SUCCESSFULLY: Expedia VN_Schedule_WB0316.xlsx
# [+] MERGED SUCCESSFULLY: Expedia VN_Schedule_WB0323.xlsx
# [+] MERGED SUCCESSFULLY: Expedia VN_Schedule_WB0330.xlsx
# [+] MERGED SUCCESSFULLY: Expedia VN_Schedule_WB0406.xlsx
# ...

# %%
# ==============================================================================
# TOOL DEBUG: HORIZONTAL TRACKING TABLE (FULLY ENGLISH & STEP-BY-STEP)
# ==============================================================================

def track_agent_schedule(target_iex, target_week):
    """
    Tracks the schedule changes of a specific agent across different processing stages.
    Features dynamic Step numbering (e.g., Step 1, Step 1.1) and step-by-step breakdown.
    Fully localized in English.
    """
    print(f"🔍 HORIZONTAL TRACKING TABLE FOR IEX ID: {target_iex} | WEEK: {target_week}")
    print("=" * 100)

    tracking_data = []
    weekdays = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

    info_cols = ['Week', 'IEX ID', 'Name', 'TL', 'Status', 'Sec Status', 'LOB', 
                 'Detailed Swap History', 'Swap Steps', 'Planned Note', 'Planned']
    
    if 'Schedule_VN' in globals():
        date_cols = [c for c in Schedule_VN.columns if c not in info_cols][:7]
    else:
        print("[!] Schedule_VN is not defined in the global scope.")
        return

    # Dictionary to keep track of the intermediate schedule state
    current_sched = {d: "" for d in date_cols}

    # ---------------------------------------------------------
    # 1. ORIGINAL SCHEDULE (Raw)
    # ---------------------------------------------------------
    row_raw = {"Stage": "★ ORIGINAL SCHEDULE (Raw)"}
    if 'schedule_step_1' in globals():
        df_raw = schedule_step_1[(schedule_step_1['Week'] == target_week) & (schedule_step_1['IEX ID'] == target_iex)]
        if not df_raw.empty:
            for d in date_cols:
                val = str(df_raw.iloc[0].get(d, ""))
                row_raw[d] = val
                current_sched[d] = val  
            row_raw['Notes'] = "Initial unprocessed schedule"
        else:
            row_raw['Notes'] = "Agent not found in raw schedule"
    tracking_data.append(row_raw)

    # ---------------------------------------------------------
    # 2. SWAP INFORMATION (Auto Step-numbering)
    # ---------------------------------------------------------
    if 'Schedule_Swap' in globals():
        df_swap = Schedule_Swap[(Schedule_Swap['IEX1'] == target_iex) | (Schedule_Swap['IEX2'] == target_iex)]
        if not df_swap.empty:
            step_counters = {}
            for idx, (_, r) in enumerate(df_swap.iterrows(), 1):
                # Read Step column, fallback to "Step X" if not found
                step_val = str(r.get('Step', f'Step {idx}')).strip()
                
                # Counter for multiple swaps within the same step
                if step_val not in step_counters:
                    step_counters[step_val] = 0
                else:
                    step_counters[step_val] += 1
                    
                count = step_counters[step_val]
                stage_name = f"Swap {step_val}" if count == 0 else f"Swap {step_val}.{count}"
                
                row_swap_req = {"Stage": f"➔ {stage_name} (Instruction)"}
                iex1 = r['IEX1']
                iex2 = r['IEX2']
                
                is_self = pd.isna(iex2) or iex1 == iex2
                partner = iex2 if iex1 == target_iex else iex1
                
                for i, day in enumerate(weekdays):
                    if i < len(date_cols):
                        val = str(r.get(day, "")).strip()
                        if val.upper() in ["NAN", "NONE"]: val = ""
                        row_swap_req[date_cols[i]] = val
                
                row_swap_req['Notes'] = "Self-change" if is_self else f"Swapped with IEX: {partner}"
                tracking_data.append(row_swap_req)
                
                # Result after this specific swap
                row_inter = {"Stage": f"   ↳ Result after {stage_name}"}
                notes_inter = []
                
                for i, day in enumerate(weekdays):
                    if i >= len(date_cols): continue
                    d_col = date_cols[i]
                    val = str(r.get(day, "")).strip()
                    val_up = val.upper()
                    
                    if is_self:
                        if val and val_up not in ["KEEP", "SWAP", "NAN", "NONE", ""]:
                            current_sched[d_col] = val
                            notes_inter.append(f"{day[:3]}: {val}")
                    else:
                        if val_up == "SWAP":
                            partner_raw = "UNKNOWN"
                            if 'schedule_step_1' in globals():
                                p_df = schedule_step_1[(schedule_step_1['Week'] == target_week) & (schedule_step_1['IEX ID'] == partner)]
                                if not p_df.empty:
                                    partner_raw = str(p_df.iloc[0].get(d_col, ""))
                            
                            current_sched[d_col] = partner_raw
                            notes_inter.append(f"{day[:3]}: got {partner_raw}")
                            
                    row_inter[d_col] = current_sched[d_col]
                
                row_inter['Notes'] = ", ".join(notes_inter) if notes_inter else "No changes"
                tracking_data.append(row_inter)
        else:
            tracking_data.append({"Stage": "➔ Swap Info", "Notes": "No swap requested"})

    # ---------------------------------------------------------
    # 3. PLANNED LEAVE INFORMATION
    # ---------------------------------------------------------
    row_leave = {"Stage": "➔ Plot AL, CO (PLANNED)"}
    row_leave_res = {"Stage": "   ↳ Result after PLANNED"}
    has_leave = False
    
    if 'Schedule_Planned' in globals():
        df_leave = Schedule_Planned[Schedule_Planned['IEX ID'] == target_iex]
        
        if not df_leave.empty:
            notes_leave = []
            for d in date_cols:
                leave_val = df_leave[df_leave['Leave Date'].astype(str) == str(d)]['Type of Request'].tolist()
                
                if leave_val:
                    has_leave = True
                    req = " | ".join(leave_val)
                    row_leave[d] = req
                    
                    if current_sched[d].upper() != "OFF":
                        current_sched[d] = req
                        notes_leave.append(f"{d[-2:]}: Applied {req}")
                    else:
                        notes_leave.append(f"{d[-2:]}: Ignored {req} (Was OFF)")
                else:
                    row_leave[d] = ""
                
                row_leave_res[d] = current_sched[d]
                
            row_leave['Notes'] = "Leave requested" if has_leave else "Leave request outside current week scope"
            row_leave_res['Notes'] = ", ".join(notes_leave) if notes_leave else ""
        else:
            row_leave['Notes'] = "No leave requested"
            
    tracking_data.append(row_leave)
    if has_leave:
        tracking_data.append(row_leave_res)

    # ---------------------------------------------------------
    # 4. FINAL RESULT (Schedule_VN)
    # ---------------------------------------------------------
    row_final = {"Stage": "★ FINAL SCHEDULE (Schedule_VN)"}
    if 'Schedule_VN' in globals():
        df_final = Schedule_VN[(Schedule_VN['Week'] == target_week) & (Schedule_VN['IEX ID'] == target_iex)]
        if not df_final.empty:
            for d in date_cols:
                row_final[d] = str(df_final.iloc[0].get(d, ""))
            
            swap_hist = str(df_final.iloc[0].get('Detailed Swap History', '')).replace('\n', ' ')
            plan_note = str(df_final.iloc[0].get('Planned Note', ''))
            
            note_str = []
            if swap_hist.strip(): note_str.append(f"[History: {swap_hist}]")
            if plan_note.strip(): note_str.append(f"[Leave Note: {plan_note}]")
            
            row_final['Notes'] = " ".join(note_str)
        else:
            row_final['Notes'] = "Agent not found in Final file"
    tracking_data.append(row_final)

    # =========================================================
    # RENDER FULL UNTRUNCATED TABLE
    # =========================================================
    tracking_df = pd.DataFrame(tracking_data).fillna("")
    
    with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):
        display(HTML(tracking_df.to_html(index=False, max_rows=None, max_cols=None)))
    
    return tracking_df

# =========================================================
# EXECUTION (Example)
# =========================================================
TARGET_IEX = 3003446  
TARGET_WEEK = week 
df_track = track_agent_schedule(TARGET_IEX, TARGET_WEEK)
# Out:
# 🔍 HORIZONTAL TRACKING TABLE FOR IEX ID: 3003446 | WEEK: Schedule_2026_05_04
# ...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stage</th>
#       <th>2026-05-04</th>
#       <th>2026-05-05</th>
#       <th>2026-05-06</th>
#       <th>2026-05-07</th>
#       <th>2026-05-08</th>
#       <th>2026-05-09</th>
#       <th>2026-05-10</th>
#       <th>Notes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>★ ORIGINAL SCHEDULE (Raw)</td>
#       <td>2000-0500</td>
#       <td>2000-0500</td>
#       <td>2000-0500</td>
#       <td>OFF</td>
#       <td>OFF</td>
#       <td>2000-0500</td>
#       <td>2000-0500</td>
#       <td>Initial unprocessed schedule</td>
#     </tr>
#     <tr>
#       <td>➔ Swap 1 (Instruction)</td>
#       <td>2000-0500</td>
#       <td>2000-0500</td>
#       <td>2000-0500</td>
#       <td>2000-0500</td>
#       <td>OFF</td>
#       <td>2000-0500</td>
#       <td>2000-0500</td>
#       <td>Self-change</td>
# ...

# %%
# ramco_file = r"C:\Users\huuchinh.nguyen\Concentrix Corporation\WFM-Expedia-HCM - Branding files\Save\EXP - CO Tracking.xlsx"
# vn_team_file = folder_paths['vn_team']  
# schedule_team_file = os.path.join(folder_paths['schedule_team'], f"{week}.xlsx")
# output_csv_path = "EXP_CO_Tracking_Export.csv"

# df_ramco = pd.read_excel(ramco_file, sheet_name="ramco_rawdata")
# df_ramco['Date'] = pd.to_datetime(df_ramco['Date'], errors='coerce')
# df_ramco['ramco_marked'] = df_ramco['ramco_marked'].astype(str).str.strip().str.upper()

# df_hc = pd.read_excel(vn_team_file, sheet_name="HC", header=None)
# df_hc.columns = df_hc.iloc[0]
# df_hc = df_hc[1:][['OracleID', 'IEX ID', 'Employee Name']].copy()
# df_hc['OracleID'] = pd.to_numeric(df_hc['OracleID'], errors='coerce')
# df_hc['IEX ID'] = pd.to_numeric(df_hc['IEX ID'], errors='coerce')
# df_hc = df_hc.dropna(subset=['OracleID', 'IEX ID']).drop_duplicates(subset=['OracleID'])

# df_sched = pd.read_excel(schedule_team_file)
# if 'IEX ID' not in df_sched.columns:
#     for idx, row in df_sched.head(15).iterrows():
#         if "IEX ID" in str(row.values):
#             df_sched.columns = row.values
#             df_sched = df_sched.iloc[idx+1:]
#             break

# active_scheduled_iex = pd.to_numeric(df_sched['IEX ID'], errors='coerce').dropna().unique()
# df_hc_active = df_hc[df_hc['IEX ID'].isin(active_scheduled_iex)]

# df_ramco['EID'] = pd.to_numeric(df_ramco['EID'], errors='coerce')
# df_merged = pd.merge(df_ramco, df_hc_active, left_on='EID', right_on='OracleID', how='inner')

# holidays_data = [
#     ("2023-01-01", "New Year's Day"), ("2023-01-21", "TET"), ("2023-01-22", "TET"), ("2023-01-23", "TET"), ("2023-01-24", "TET"), ("2023-01-25", "TET"),
#     ("2023-04-29", "KING'S DAY"), ("2023-04-30", "Reunification Day"), ("2023-05-01", "Labor Day"), ("2023-09-01", "Independence Day"), ("2023-09-02", "Independence Day"),
#     ("2024-01-01", "New Year's Day"), ("2024-02-09", "TET"), ("2024-02-10", "TET"), ("2024-02-11", "TET"), ("2024-02-12", "TET"), ("2024-02-13", "TET"),
#     ("2024-04-18", "KING'S DAY"), ("2024-04-30", "Reunification Day"), ("2024-05-01", "Labor Day"), ("2024-09-02", "Independence Day"), ("2024-09-03", "Independence Day"),
#     ("2025-01-01", "New Year's Day"), ("2025-01-28", "TET"), ("2025-01-29", "TET"), ("2025-01-30", "TET"), ("2025-01-31", "TET"), ("2025-02-01", "TET"),
#     ("2025-04-07", "KING'S DAY"), ("2025-04-30", "Reunification Day"), ("2025-05-01", "Labor Day"), ("2025-09-01", "Independence Day"), ("2025-09-02", "Independence Day"),
#     ("2026-01-01", "New Year's Day"), ("2026-02-16", "TET"), ("2026-02-17", "TET"), ("2026-02-18", "TET"), ("2026-02-19", "TET"), ("2026-02-20", "TET"),
#     ("2026-04-26", "KING'S DAY"), ("2026-04-30", "Reunification Day"), ("2026-05-01", "Labor Day"), ("2026-09-01", "Independence Day"), ("2026-09-02", "Independence Day"),
#     ("2027-01-01", "New Year's Day"), ("2027-02-05", "TET"), ("2027-02-06", "TET"), ("2027-02-07", "TET"), ("2027-02-08", "TET"), ("2027-02-09", "TET"),
#     ("2027-04-16", "KING'S DAY"), ("2027-04-30", "Reunification Day"), ("2027-05-01", "Labor Day"), ("2027-09-02", "Independence Day"), ("2027-09-03", "Independence Day")
# ]

# df_holidays = pd.DataFrame(holidays_data, columns=['Date', 'Holiday_Name'])
# df_holidays['Date'] = pd.to_datetime(df_holidays['Date'])
# df_holidays['Is_Holiday'] = 1

# df = pd.merge(df_merged, df_holidays, on='Date', how='left')
# df['Is_Holiday'] = df['Is_Holiday'].fillna(0)

# df = df.sort_values(by=['IEX ID', 'Date'])

# df['Is_WO'] = np.where(df['ramco_marked'] == 'WO', 1, 0)
# df['Is_PH'] = np.where(df['ramco_marked'] == 'PH', 1, 0)
# df['Is_PO'] = np.where(df['ramco_marked'] == 'PO', 1, 0)
# df['Is_NM'] = np.where(df['ramco_marked'] == 'NM', 1, 0)  # Thêm logic bắt NM
# df['WO_on_Holiday'] = np.where((df['Is_Holiday'] == 1) & (df['Is_WO'] == 1), 1, 0)

# df['Week_Start_Monday'] = df['Date'] - pd.to_timedelta(df['Date'].dt.weekday, unit='d')
# df['Week_Start_Monday'] = df['Week_Start_Monday'].dt.strftime('%Y-%m-%d')
# df['Holiday_Info'] = np.where(df['Is_Holiday'] == 1, df['Date'].dt.strftime('%d/%m') + " - " + df['Holiday_Name'].astype(str), "")

# df['Daily_Log'] = np.where(
#     (df['ramco_marked'].notna()) & (df['ramco_marked'] != "NAN") & (df['ramco_marked'] != ""),
#     df['Date'].dt.strftime('%d/%m') + " - " + df['ramco_marked'],
#     ""
# )

# weekly_summary = df.groupby(['IEX ID', 'OracleID', 'Employee Name', 'Week_Start_Monday']).agg(
#     Total_OFF=('Is_WO', 'sum'),
#     Total_PH=('Is_PH', 'sum'),
#     Total_PO=('Is_PO', 'sum'),
#     Total_NM=('Is_NM', 'sum'),
#     Target_HO=('Is_Holiday', 'sum'),
#     WO_on_Holiday=('WO_on_Holiday', 'sum'),
#     Holiday_Notes=('Holiday_Info', lambda x: " | ".join(sorted(list(set(i for i in x if i != ""))))),
#     Log=('Daily_Log', lambda x: ", ".join([i for i in x if i != ""]))
# ).reset_index()

# weekly_summary['Total_CO_Taken'] = np.maximum(0, weekly_summary['Total_OFF'] - 2)
# weekly_summary['Applied_HO'] = np.maximum(0, weekly_summary['Target_HO'] - weekly_summary['Total_PH'])

# missing_wo = np.maximum(0, 2 - (weekly_summary['Total_OFF'] + weekly_summary['Total_PO']))
# weekly_summary['Total_CO_Earned'] = np.minimum(weekly_summary['Applied_HO'], missing_wo + weekly_summary['WO_on_Holiday'])

# weekly_summary = weekly_summary.sort_values(by=['IEX ID', 'Week_Start_Monday']).reset_index(drop=True)

# weekly_summary = weekly_summary[
#     (weekly_summary['Total_OFF'] > 0) | 
#     (weekly_summary['Target_HO'] > 0) | 
#     (weekly_summary['Total_PH'] > 0) | 
#     (weekly_summary['Total_PO'] > 0) |
#     (weekly_summary['Total_NM'] > 0)
# ]

# final_columns = ['IEX ID', 'OracleID', 'Employee Name', 'Week_Start_Monday', 'Total_OFF', 'Total_PH', 'Total_PO', 'Total_NM', 'Target_HO', 'Applied_HO', 'Total_CO_Earned', 'Total_CO_Taken', 'Holiday_Notes', 'Log']
# weekly_summary = weekly_summary[final_columns]

# weekly_summary.to_csv(output_csv_path, index=False, encoding='utf-8-sig')

# print(f"\n[ ✅ COMPLETED: WEEKLY CO TRACKING EXPORTED TO CSV ]\n📁 Path: {os.path.abspath(output_csv_path)}\n")
